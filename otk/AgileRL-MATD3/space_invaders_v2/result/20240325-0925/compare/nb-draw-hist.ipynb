# %%
#!pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 6.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 7.1 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 7.7 MB/s eta 0:00:000:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# Frames_count_100.csv  nb-draw-hist.ipynb  Untitled.ipynb

# %%
df = pd.read_csv("Frames_count_100.csv")

# %%
df
# Out:
#     1000steps  10000steps  5000steps
# 0         291         426        527
# 1         464         331        315
# 2         487         316        416
# 3         500         275        298
# 4         573         321        395
# ..        ...         ...        ...
# 95        425         380        237
# 96        300         766        321
# 97        580         558        303
# 98        286         339        653
# 99        300         271        418
#
# [100 rows x 3 columns]

# %%
df["1000steps"].hist(bins=50)
plt.ylim(0,12)
plt.xlim(0,1200)
plt.title("01000eps")
plt.ylabel("times")
plt.xlabel("alive frames")
plt.savefig("hist01000.png")

# %%
df["5000steps"].hist(bins=50)
plt.ylim(0,12)
plt.xlim(0,1200)
plt.title("05000eps")
plt.ylabel("times")
plt.xlabel("alive frames")
plt.savefig("hist05000.png")

# %%
df["10000steps"].hist(bins=50)
plt.ylim(0,12)
plt.xlim(0,1200)
plt.title("10000eps")
plt.ylabel("times")
plt.xlabel("alive frames")
plt.savefig("hist10000.png")
